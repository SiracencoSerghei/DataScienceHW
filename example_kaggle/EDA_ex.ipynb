# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Завантажуємо дані
df = pd.read_csv('data.csv')

# Огляд даних
print(df.head())  # Перегляд перших рядків
print(df.info())  # Інформація про колонки
print(df.describe())  # Описова статистика

# Перевірка на пропуски
print(df.isnull().sum())

# Обробка пропусків
# Numeric columns: Fill with the mean
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].mean())

# Categorical columns: Fill with "Unknown"
categorical_cols = df.select_dtypes(include=['object']).columns
df[categorical_cols] = df[categorical_cols].fillna('Unknown')

# Перевірка, що всі пропуски заповнені
print(df.isnull().sum())

# Візуалізація розподілу змінних
sns.histplot(df['Salary'])
plt.title('Розподіл змінної Salary')
plt.show()

# Фільтруємо тільки числові колонки для кореляції
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Кореляція між змінними
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title('Кореляція між змінними')
plt.show()

# Boxplot для виявлення аномалій
sns.boxplot(x=df['Salary'])
plt.title('Ящик з вусами для Salary')
plt.show()
# Out:
#     Age   Salary Department  Years_at_Company  Performance_Score
# 0  25.0  50000.0         HR               1.0                4.5
# 1  30.0  60000.0         IT               3.0                3.7
# 2  35.0  70000.0         IT               5.0                NaN
# 3  40.0  80000.0    Finance               7.0                4.2
# 4   NaN  55000.0         HR               2.0                3.8
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Age                8 non-null      float64
#  1   Salary             8 non-null      float64
#  2   Department         10 non-null     object
#  3   Years_at_Company   9 non-null      float64
#  4   Performance_Score  8 non-null      float64
# dtypes: float64(4), object(1)
# memory usage: 532.0+ bytes
# None
#              Age         Salary  Years_at_Company  Performance_Score
# ...
