# %%
# !pip install matplotlib

# %%
# !pip install numpy

# %%
import matplotlib.pyplot as plt

import numpy as np

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
# axes with tile shoes vs time
plt.title('Shoes sales over time')
plt.xlabel('time')
plt.ylabel('sin(x)')
plt.show()

# %% [markdown]
# The shoes sales follow a sinusoidal $f(x) = sin(x)$ pattern. Recomendation to avoid overstock during periods of low demand.

# %%
v1 = np.random.randint(0, 10, (2,))
v2 = np.random.randint(0, 10,(2,))
v1, v2
# Out:
# (array([8, 1]), array([9, 6]))

# %%
# plt.scatter(x=[v1[0], v1[1]], y=[v2[0], v2[1]])
plt.arrow(0, 0, v1[0], v2[0], color="r")
plt.arrow(0, 0, v1[1], v2[1], color="b")
plt.title("vectors")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.axis("equal")
plt.show()

# %%
A = np.random.randint(0, 10,(3,3))
B = np.random.randint(0, 10, (3, 3))
A, B
# Out:
# (array([[0, 8, 3],
#         [6, 9, 1],
#         [0, 9, 4]]),
#  array([[3, 8, 2],
#         [8, 7, 7],
#         [8, 5, 1]]))

# %%
A@B
# Out:
# array([[ 88,  71,  59],
#        [ 98, 116,  76],
#        [104,  83,  67]])

# %%
# !pip install torch torchvision
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━ 575.2/779.1 MB 2.2 MB/s eta 0:01:35m
# ERROR: Exception:
# Traceback (most recent call last):
#   File "/home/sergio/.local/lib/python3.12/site-packages/pip/_vendor/urllib3/response.py", line 438, in _error_catcher
#     yield
#   File "/home/sergio/.local/lib/python3.12/site-packages/pip/_vendor/urllib3/response.py", line 561, in read
#     data = self._fp_read(amt) if not fp_closed else b""
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/sergio/.local/lib/python3.12/site-packages/pip/_vendor/urllib3/response.py", line 527, in _fp_read
#     return self._fp.read(amt) if amt is not None else self._fp.read()
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/sergio/.local/lib/python3.12/site-packages/pip/_vendor/cachecontrol/filewrapper.py", line 98, in read
#     data: bytes = self.__fp.read(amt)
#                   ^^^^^^^^^^^^^^^^^^^
#   File "/home/sergio/anaconda3/envs/myenv/lib/python3.12/http/client.py", line 479, in read
# ...

# %%
import torch
from torchvision.transforms import functional as TF

C = torch.rand(3, 256, 256)
image = TF.to_pil_image(C)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 import torch
#       2 from torchvision.transforms import functional as TF
#       4 C = torch.rand(3, 256, 256)
#
# ModuleNotFoundError: No module named 'torch'
